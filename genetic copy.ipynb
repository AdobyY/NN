# %%
import numpy as np  
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
df = sm.datasets.macrodata.load_pandas().data

# Функція для створення дати з року та кварталу
def create_date(row):
    return pd.Timestamp(year=int(row['year']), month=int(row['quarter'] * 3 - 2), day=1)

df['date'] = df.apply(create_date, axis=1)
year = df.drop_duplicates("year")
year = df

X = df[['realgdp', 'realcons', 'realinv', 'realgovt',
        'realdpi', 'm1', 'tbilrate', 'unemp', 'pop', 'infl', 'realint']].values
# X = df[['realgdp', 'realcons', 'realinv', 'realgovt']].values 
y = df['cpi'].values  # Цільова змінна

y = y.reshape(-1, 1)

# %%
from model import NeuralNetwork
from layers import DenseLayer
from optimizers import GD
from activations import *


model = NeuralNetwork(X.shape[1])
model.add_layer(DenseLayer(num_inputs=X.shape[1], num_neurons=16, activation_func=Tanh()))
model.add_layer(DenseLayer(num_inputs=16, num_neurons=1, activation_func=ReLU()))

model.load_weights("model_weights.pkl")

history = model.fit(X, y, epochs=1000, optimizer=GD(learning_rate=0.001))
# Out:
# Epoch 0: Loss = 9.326123191099497e+38
# Epoch 100: Loss = 14777.52408308867
# Epoch 200: Loss = 14777.52408308867
# Epoch 300: Loss = 14777.52408308867
# Epoch 400: Loss = 14777.52408308867
# Epoch 500: Loss = 14777.52408308867
# Epoch 600: Loss = 14777.52408308867
# Epoch 700: Loss = 14777.52408308867
# Epoch 800: Loss = 14777.52408308867
# Epoch 900: Loss = 14777.52408308867

# %%
def sliding_window_training(X, y, folder, window_size=12, num_windows=10): 
    for window in range(num_windows):  # Цикл для всіх вікон
        start_index = window
        end_index = start_index + window_size
        
        if end_index > len(X):
            print("End of data reached.")
            break  # Вихід, якщо виходимо за межі даних
        
        print(f"Training on window {window + 1} ({start_index}-{end_index})")
        
        X_window = X[start_index:end_index] 
        y_window = y[start_index:end_index]

        # Навчання мережі на поточному вікні
        model.fit(X_window, y_window, epochs=1000, optimizer=GD())
        # Прогнозування 
        predictions = model.forward(X_window)

        # Розрахунок DELTA та DELTA^2
        delta = predictions.flatten() - y_window.flatten()
        delta_squared = delta ** 2
        
        # Підготовка даних для таблиці
        results_df = pd.DataFrame({
            'Point': np.arange(window_size)[::-1],
            'IPC RO': y_window.flatten(),
            'IPC PO': predictions.flatten(),
            'DELTA': delta,
            'DELTA^2': delta_squared
        })
        
        # Обчислення TOTAL та MSE
        total_delta = delta.sum()
        total_delta_squared = delta_squared.sum()
        mse = np.mean(delta_squared)

        # Додавання підсумків до таблиці
        results_df.loc[len(results_df)] = ['TOTAL', '', total_delta, '', total_delta_squared]
        results_df.loc[len(results_df)] = ['MSE', '', '', '', mse]

        # Збереження результатів у Excel
        results_df.to_excel(f'{folder}/sliding_window_results_window_{window + 1}.xlsx', index=False)

        # Візуалізація
        plt.figure(figsize=(10, 6))
        plt.plot(df['date'][start_index:end_index], y_window, label='Реальні значення', color='blue')
        plt.plot(df['date'][start_index:end_index], predictions, label='Прогнози', linestyle='--', color='orange')
        plt.xlabel('Дата')
        plt.ylabel('Індекс споживчих цін')
        plt.title(f'Прогнозування для вікна {window + 1} ({start_index}-{end_index})')
        plt.legend()

        plt.text(0.05, 0.95, f'MSE: {mse:.4f}', transform=plt.gca().transAxes,
                 fontsize=12, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.5))

        plt.savefig(f'{folder}/window_{window + 1}_forecast.png')  # Зберігаємо графік
        plt.show()

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
sliding_window_training(X_scaled, y, "full", window_size=50, num_windows=10)
# Out:
# Training on window 1 (0-50)
# Epoch 0: Loss = 1088.403778
# Epoch 100: Loss = 1088.403778
# Epoch 200: Loss = 1088.403778
# c:\Users\b.yarinko\Desktop\Code\NN\activations.py:12: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# Epoch 300: Loss = 1088.403778
# Epoch 400: Loss = 1088.403778
# Epoch 500: Loss = 1088.403778
# Epoch 600: Loss = 1088.403778
# Epoch 700: Loss = 1088.403778
# Epoch 800: Loss = 1088.403778
# Epoch 900: Loss = 1088.403778
# Training on window 2 (1-51)
# Epoch 0: Loss = 1105.0631700000001
# Epoch 100: Loss = 1105.0631700000001
# Epoch 200: Loss = 1105.0631700000001
# c:\Users\b.yarinko\Desktop\Code\NN\activations.py:12: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# Epoch 300: Loss = 1105.0631700000001
# Epoch 400: Loss = 1105.0631700000001
# Epoch 500: Loss = 1105.0631700000001
# Epoch 600: Loss = 1105.0631700000001
# Epoch 700: Loss = 1105.0631700000001
# Epoch 800: Loss = 1105.0631700000001
# Epoch 900: Loss = 1105.0631700000001
# Training on window 3 (2-52)
# Epoch 0: Loss = 1122.01752
# Epoch 100: Loss = 1122.01752
# c:\Users\b.yarinko\Desktop\Code\NN\activations.py:12: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# Epoch 200: Loss = 1122.01752
# Epoch 300: Loss = 1122.01752
# Epoch 400: Loss = 1122.01752
# Epoch 500: Loss = 1122.01752
# Epoch 600: Loss = 1122.01752
# Epoch 700: Loss = 1122.01752
# Epoch 800: Loss = 1122.01752
# Epoch 900: Loss = 1122.01752
# Training on window 4 (3-53)
# Epoch 0: Loss = 1139.23407
# Epoch 100: Loss = 1139.23407
# Epoch 200: Loss = 1139.23407
# c:\Users\b.yarinko\Desktop\Code\NN\activations.py:12: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# Epoch 300: Loss = 1139.23407
# Epoch 400: Loss = 1139.23407
# Epoch 500: Loss = 1139.23407
# Epoch 600: Loss = 1139.23407
# Epoch 700: Loss = 1139.23407
# Epoch 800: Loss = 1139.23407
# Epoch 900: Loss = 1139.23407
# Training on window 5 (4-54)
# Epoch 0: Loss = 1156.9269319999999
# Epoch 100: Loss = 1156.9269319999999
# Epoch 200: Loss = 1156.9269319999999
# c:\Users\b.yarinko\Desktop\Code\NN\activations.py:12: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# Epoch 300: Loss = 1156.9269319999999
# Epoch 400: Loss = 1156.9269319999999
# Epoch 500: Loss = 1156.9269319999999
# Epoch 600: Loss = 1156.9269319999999
# Epoch 700: Loss = 1156.9269319999999
# Epoch 800: Loss = 1156.9269319999999
# Epoch 900: Loss = 1156.9269319999999
# Training on window 6 (5-55)
# Epoch 0: Loss = 1175.0915
# Epoch 100: Loss = 1175.0915
# Epoch 200: Loss = 1175.0915
# c:\Users\b.yarinko\Desktop\Code\NN\activations.py:12: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# Epoch 300: Loss = 1175.0915
# Epoch 400: Loss = 1175.0915
# Epoch 500: Loss = 1175.0915
# Epoch 600: Loss = 1175.0915
# Epoch 700: Loss = 1175.0915
# Epoch 800: Loss = 1175.0915
# Epoch 900: Loss = 1175.0915
# Training on window 7 (6-56)
# Epoch 0: Loss = 1194.09325
# Epoch 100: Loss = 1194.09325
# Epoch 200: Loss = 1194.09325
# c:\Users\b.yarinko\Desktop\Code\NN\activations.py:12: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# Epoch 300: Loss = 1194.09325
# Epoch 400: Loss = 1194.09325
# Epoch 500: Loss = 1194.09325
# Epoch 600: Loss = 1194.09325
# Epoch 700: Loss = 1194.09325
# Epoch 800: Loss = 1194.09325
# Epoch 900: Loss = 1194.09325
# Training on window 8 (7-57)
# Epoch 0: Loss = 1214.5858
# Epoch 100: Loss = 1214.5858
# Epoch 200: Loss = 1214.5858
# c:\Users\b.yarinko\Desktop\Code\NN\activations.py:12: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# Epoch 300: Loss = 1214.5858
# Epoch 400: Loss = 1214.5858
# Epoch 500: Loss = 1214.5858
# Epoch 600: Loss = 1214.5858
# Epoch 700: Loss = 1214.5858
# Epoch 800: Loss = 1214.5858
# Epoch 900: Loss = 1214.5858
# Training on window 9 (8-58)
# Epoch 0: Loss = 1235.8500880000001
# Epoch 100: Loss = 1235.8500880000001
# Epoch 200: Loss = 1235.8500880000001
# c:\Users\b.yarinko\Desktop\Code\NN\activations.py:12: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# Epoch 300: Loss = 1235.8500880000001
# Epoch 400: Loss = 1235.8500880000001
# Epoch 500: Loss = 1235.8500880000001
# Epoch 600: Loss = 1235.8500880000001
# Epoch 700: Loss = 1235.8500880000001
# Epoch 800: Loss = 1235.8500880000001
# Epoch 900: Loss = 1235.8500880000001
# Training on window 10 (9-59)
# Epoch 0: Loss = 1259.6645660000001
# Epoch 100: Loss = 1259.6645660000001
# Epoch 200: Loss = 1259.6645660000001
# c:\Users\b.yarinko\Desktop\Code\NN\activations.py:12: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# Epoch 300: Loss = 1259.6645660000001
# Epoch 400: Loss = 1259.6645660000001
# Epoch 500: Loss = 1259.6645660000001
# Epoch 600: Loss = 1259.6645660000001
# Epoch 700: Loss = 1259.6645660000001
# Epoch 800: Loss = 1259.6645660000001
# Epoch 900: Loss = 1259.6645660000001

# %%
model.save_weights("model_weights.pkl")

# %%
year_part = df.drop_duplicates("year")
# year = df

# X = year[['realgdp', 'realcons', 'realinv', 'realgovt',
#         'realdpi', 'm1', 'tbilrate', 'unemp', 'pop', 'infl', 'realint']].values
X_part = df[['realgdp', 'realcons', 'realinv', 'realgovt']].values 
y_part = df['cpi'].values  # Цільова змінна

y_part = y_part.reshape(-1, 1)

# %%
X_scaled = scaler.fit_transform(X_part)

# Створення моделі
model = NeuralNetwork(X_part.shape[1])
model.add_layer(DenseLayer(num_inputs=X_part.shape[1], num_neurons=8, activation_func=ReLU()))
model.add_layer(DenseLayer(num_inputs=8, num_neurons=1, activation_func=ReLU()))

# Налаштування оптимізатора
optimizer = GeneticOptimizer(population_size=50, mutation_rate=0.1)

sliding_window_training(X_scaled, y_part, "partial", window_size=50, num_windows=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 9
#       6 model.add_layer(DenseLayer(num_inputs=8, num_neurons=1, activation_func=ReLU()))
#       8 # Налаштування оптимізатора
# ----> 9 optimizer = GeneticOptimizer(population_size=50, mutation_rate=0.1)
#      11 sliding_window_training(X_scaled, y_part, "partial", window_size=50, num_windows=10)
#
# NameError: name 'GeneticOptimizer' is not defined
